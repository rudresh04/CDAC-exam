# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Data Understanding and Preprocessing:

# %%
df = pd.read_csv('Stats-Module_End_Data.csv')   ## Loading data

# %%
df.head()   ## From this we will get first five values of data
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.shape  ## This gives us the shape of the data in (rows , columns) format
# Out:
# (6819, 96)

# %%
df.columns  ## Gives the full list of columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
df.info()  ## Gives the basic information of data (index,column_name,number_of_columns,null_or_non-null,data_type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
pd.set_option('display.max_columns',None)   ## set_option is used to set a particular option , here we want maximum number of columns to be displayed.
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.corr()   ## Shows the correlation of the data.
# Out:
#                                                     Bankrupt?  \
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
#                                                      ROA(C) before interest and depreciation before interest  \
# Bankrupt?                                                                                   -0.260807
# ...

# %%
df[' Liability-Assets Flag'].value_counts()   ## value_counts gives the total values present in that column
# Out:
#  Liability-Assets Flag
# 0    6811
# 1       8
# Name: count, dtype: int64

# %%
df['Bankrupt?'].value_counts()
# Out:
# Bankrupt?
# 0    6599
# 1     220
# Name: count, dtype: int64

# %%
df[' Net Income Flag'].value_counts()
# Out:
#  Net Income Flag
# 1    6819
# Name: count, dtype: int64

# %% [markdown]
# ### Here we taken only those values whose corelation is not equal to 0.

# %%
df[df[' Liability-Assets Flag']!=0]
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 56            1                                           0.066933
# 1869          1                                           0.392775
# 1870          1                                           0.277726
# 2001          1                                           0.438795
# 2470          1                                           0.404036
# 2735          0                                           0.436894
# 6613          0                                           0.279676
# 6640          1                                           0.196802
#
#        ROA(A) before interest and % after tax  \
# 56                                   0.057185
# 1869                                 0.432239
# 1870                                 0.314708
# 2001                                 0.090166
# 2470                                 0.223615
# 2735                                 0.453718
# ...

# %% [markdown]
# ### We are checking those values which are greater than 0.10 and getting there index and taking it in list format

# %%
(df.corr()[['Bankrupt?']]>0.10).index.to_list()
# Out:
# ['Bankrupt?',
#  ' ROA(C) before interest and depreciation before interest',
#  ' ROA(A) before interest and % after tax',
#  ' ROA(B) before interest and depreciation after tax',
#  ' Operating Gross Margin',
#  ' Realized Sales Gross Margin',
#  ' Operating Profit Rate',
#  ' Pre-tax net Interest Rate',
#  ' After-tax net Interest Rate',
#  ' Non-industry income and expenditure/revenue',
#  ' Continuous interest rate (after tax)',
#  ' Operating Expense Rate',
#  ' Research and development expense rate',
#  ' Cash flow rate',
#  ' Interest-bearing debt interest rate',
#  ' Tax rate (A)',
#  ' Net Value Per Share (B)',
#  ' Net Value Per Share (A)',
#  ' Net Value Per Share (C)',
#  ' Persistent EPS in the Last Four Seasons',
#  ' Cash Flow Per Share',
#  ' Revenue Per Share (Yuan ¥)',
#  ' Operating Profit Per Share (Yuan ¥)',
#  ' Per Share Net profit before tax (Yuan ¥)',
#  ' Realized Sales Gross Profit Growth Rate',
#  ' Operating Profit Growth Rate',
# ...

# %%
corrMatrix = df.corr()[['Bankrupt?']]
corrMatrix
# Out:
#                                                     Bankrupt?
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
# [96 rows x 1 columns]

# %% [markdown]
# #### values less than or equal to 0.15 are stored in ltindex
# #### values less than or equal to 0.15 are stored in gtindex

# %%
ltindex = corrMatrix.loc[corrMatrix['Bankrupt?'] <= -0.15].index

# %%
gtindex = corrMatrix.loc[corrMatrix['Bankrupt?'] >= 0.15].index

# %%
df1 = df[ltindex]  ## Storing old dataframe ltindex into new dataframe

# %%
df2 = df[gtindex]  ## Storing old dataframe gtindex into new dataframe

# %%
bank = pd.concat([df1,df2],axis=1)   ## Concating both new data frames

# %%
bank.columns
# Out:
# Index([' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Per Share Net profit before tax (Yuan ¥)', ' Net worth/Assets',
#        ' Net profit before tax/Paid-in capital',
#        ' Working Capital to Total Assets',
#        ' Retained Earnings to Total Assets', ' Net Income to Total Assets',
#        ' Net Income to Stockholder's Equity', 'Bankrupt?', ' Debt ratio %',
#        ' Borrowing dependency', ' Current Liability to Assets',
#        ' Current Liabilities/Equity', ' Current Liability to Equity',
#        ' Current Liability to Current Assets', ' Liability to Equity'],
#       dtype='object')

# %%
bank.shape
# Out:
# (6819, 22)

# %% [markdown]
# ### Checking Null values and their counts in every column

# %%
bank.isna().sum()
# Out:
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Net Value Per Share (B)                                    0
#  Net Value Per Share (A)                                    0
#  Net Value Per Share (C)                                    0
#  Persistent EPS in the Last Four Seasons                    0
#  Per Share Net profit before tax (Yuan ¥)                   0
#  Net worth/Assets                                           0
#  Net profit before tax/Paid-in capital                      0
#  Working Capital to Total Assets                            0
#  Retained Earnings to Total Assets                          0
#  Net Income to Total Assets                                 0
#  Net Income to Stockholder's Equity                         0
# Bankrupt?                                                   0
# ...

# %%
bank.corr()['Bankrupt?']  ## Checking corelation of all the columns with Bankrupt column
# Out:
#  ROA(C) before interest and depreciation before interest   -0.260807
#  ROA(A) before interest and % after tax                    -0.282941
#  ROA(B) before interest and depreciation after tax         -0.273051
#  Net Value Per Share (B)                                   -0.165399
#  Net Value Per Share (A)                                   -0.165465
#  Net Value Per Share (C)                                   -0.164784
#  Persistent EPS in the Last Four Seasons                   -0.219560
#  Per Share Net profit before tax (Yuan ¥)                  -0.201395
#  Net worth/Assets                                          -0.250161
#  Net profit before tax/Paid-in capital                     -0.207857
#  Working Capital to Total Assets                           -0.193083
#  Retained Earnings to Total Assets                         -0.217779
#  Net Income to Total Assets                                -0.315457
#  Net Income to Stockholder's Equity                        -0.180987
# ...

# %%
import seaborn as sns   ## Used this for plotting graphs

# %%
bank
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# 6817                                           0.506264
# 6818                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...

# %% [markdown]
# ### Renamed columns for better extraction and easy access

# %%
d={' ROA(C) before interest and depreciation before interest':'ROA(C)',' ROA(A) before interest and % after tax':'ROA(A)',' ROA(B) before interest and depreciation after tax':'ROA(B)',
   ' Net Value Per Share (B)':'Net_Value(B)',' Net Value Per Share (A)':'Net_Value(A)',' Net Value Per Share (C)':'Net_Value(C)',' Persistent EPS in the Last Four Seasons':'EPS',' Per Share Net profit before tax (Yuan ¥)':'Net_profit_before_tax(Yuan)',
   ' Net worth/Assets':'Net_Worth',' Net profit before tax/Paid-in capital':'Net_profit_before_tax/paid',' Working Capital to Total Assets':'Working_capital',' Retained Earnings to Total Assets':'Retained_Earnings',' Net Income to Total Assets':'Net_Income_Total'," Net Income to Stockholder's Equity":'Net_Income_Stockholder',
   'Bankrupt?':'Bankrupt',' Debt ratio %':'Debt_ratio(Percent)',' Borrowing dependency':'Borrow_depend',' Current Liability to Assets':'current_Liability/Assets',' Current Liabilities/Equity':'Current_Liabilities/Equity',' Current Liability to Equity':'Current_Liability_to_Equity',' Current Liability to Current Assets':'Current_Liability_to_Current_Assets',
   ' Liability to Equity':'Liability_to_Equity'
  }

# %%
bank=bank.rename(columns=d)

# %%
df1 = bank.iloc[:,0:15]  ## Storing columns 0 to 14 in df1

# %%
df2 = bank.iloc[:,15:]   ## Storing columns 15 to end in df2

# %%
bank = pd.concat([df1,df2],axis=1)  ## Joining df1 and df2

# %%
bank.head()
# Out:
#      ROA(C)    ROA(A)    ROA(B)  Net_Value(B)  Net_Value(A)  Net_Value(C)  \
# 0  0.370594  0.424389  0.405750      0.147950      0.147950      0.147950
# 1  0.464291  0.538214  0.516730      0.182251      0.182251      0.182251
# 2  0.426071  0.499019  0.472295      0.177911      0.177911      0.193713
# 3  0.399844  0.451265  0.457733      0.154187      0.154187      0.154187
# 4  0.465022  0.538432  0.522298      0.167502      0.167502      0.167502
#
#         EPS  Net_profit_before_tax(Yuan)  Net_Worth  \
# 0  0.169141                     0.138736   0.792424
# 1  0.208944                     0.169918   0.828824
# 2  0.180581                     0.142803   0.792484
# 3  0.193722                     0.148603   0.848535
# 4  0.212537                     0.168412   0.893491
#
#    Net_profit_before_tax/paid  Working_capital  Retained_Earnings  \
# 0                    0.137757         0.672775           0.903225
# 1                    0.168962         0.751111           0.931065
# ...

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA):

# %% [markdown]
# ### Plotted Bar graph to visualize the Discrete data

# %%
bank.Bankrupt.value_counts().plot(kind='bar', figsize=(9,5))
# Out:
# <Axes: xlabel='Bankrupt'>

# %%
bank.corr()['Bankrupt']
# Out:
# ROA(C)                                -0.260807
# ROA(A)                                -0.282941
# ROA(B)                                -0.273051
# Net_Value(B)                          -0.165399
# Net_Value(A)                          -0.165465
# Net_Value(C)                          -0.164784
# EPS                                   -0.219560
# Net_profit_before_tax(Yuan)           -0.201395
# Net_Worth                             -0.250161
# Net_profit_before_tax/paid            -0.207857
# Working_capital                       -0.193083
# Retained_Earnings                     -0.217779
# Net_Income_Total                      -0.315457
# Net_Income_Stockholder                -0.180987
# Bankrupt                               1.000000
# Debt_ratio(Percent)                    0.250161
# Borrow_depend                          0.176543
# current_Liability/Assets               0.194494
# Current_Liabilities/Equity             0.153828
# Current_Liability_to_Equity            0.153828
# ...

# %% [markdown]
# ### Plotted Histogram for corelation values

# %%
sns.heatmap(bank.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Created Function to impute our outliers in lower bound and upper bound

# %%
def outlier(x):
    Q3=bank[x].quantile(0.75)
    Q1=bank[x].quantile(0.25)
    IQR=Q3-Q1
    lb=Q1-1.5*(IQR)
    ub=Q3+1.5*(IQR)
    idx=np.where(bank[x]>ub)
    bank[x].iloc[idx]=ub
    idx1=np.where(bank[x]<lb)
    bank[x].iloc[idx1]=lb

# %%
bank.corr()['Bankrupt']
# Out:
# ROA(C)                                -0.260807
# ROA(A)                                -0.282941
# ROA(B)                                -0.273051
# Net_Value(B)                          -0.165399
# Net_Value(A)                          -0.165465
# Net_Value(C)                          -0.164784
# EPS                                   -0.219560
# Net_profit_before_tax(Yuan)           -0.201395
# Net_Worth                             -0.250161
# Net_profit_before_tax/paid            -0.207857
# Working_capital                       -0.193083
# Retained_Earnings                     -0.217779
# Net_Income_Total                      -0.315457
# Net_Income_Stockholder                -0.180987
# Bankrupt                               1.000000
# Debt_ratio(Percent)                    0.250161
# Borrow_depend                          0.176543
# current_Liability/Assets               0.194494
# Current_Liabilities/Equity             0.153828
# Current_Liability_to_Equity            0.153828
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotted box plot before removing outliers

# %%
for feature in bank:
    bank.boxplot(feature, vert=False)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Used for loop to impute outliers of all the columns in one go

# %%
for i in bank:
    if i!='Bankrupt':
        outlier(i)
# Out:
# C:\Users\Rudresh\AppData\Local\Temp\ipykernel_20196\958331113.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank[x].iloc[idx]=ub
# C:\Users\Rudresh\AppData\Local\Temp\ipykernel_20196\958331113.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank[x].iloc[idx1]=lb
# C:\Users\Rudresh\AppData\Local\Temp\ipykernel_20196\958331113.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank[x].iloc[idx]=ub
# ...

# %% [markdown]
# ### Plotted Box plot after outliers imputed

# %%
for feature in bank:
    bank.boxplot(feature, vert=False)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## Generate descriptive statistics.

# %%
bank.describe()
# Out:
#             ROA(C)       ROA(A)       ROA(B)  Net_Value(B)  Net_Value(A)  \
# count  6819.000000  6819.000000  6819.000000   6819.000000   6819.000000
# mean      0.505667     0.560507     0.554691      0.188108      0.188098
# std       0.051483     0.050087     0.050277      0.022773      0.022825
# min       0.387973     0.455122     0.442034      0.134676      0.134676
# 25%       0.476527     0.535543     0.527277      0.173613      0.173613
# 50%       0.502706     0.559802     0.552278      0.184400      0.184400
# 75%       0.535563     0.589157     0.584105      0.199570      0.199570
# max       0.624116     0.669579     0.669348      0.238507      0.238507
#
#        Net_Value(C)          EPS  Net_profit_before_tax(Yuan)    Net_Worth  \
# count   6819.000000  6819.000000                  6819.000000  6819.000000
# mean       0.188134     0.227074                     0.182461     0.887070
# std        0.022829     0.021870                     0.020916     0.052337
# ...

# %%
sns.countplot(x='Bankrupt',data=bank)
# Out:
# <Axes: xlabel='Bankrupt', ylabel='count'>

# %%
bank.hist(figsize=(20,20))
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(bank.corr(),annot=True)
plt.show()

# %% [markdown]
# # 3. Hypothesis Testing:

# %%
from scipy.stats import ttest_ind

significant_features = []
for column in bank.select_dtypes(include=[np.number]).columns:
    if column != 'Bankrupt':
        bankrupt = bank[bank['Bankrupt'] == 1][column]
        non_bankrupt = bank[bank['Bankrupt'] == 0][column]
        t_stat, p_val = ttest_ind(bankrupt, non_bankrupt)
        if p_val < 0.05:
            significant_features.append(column)
        print(f'{column}: t-statistic={t_stat}, p-value={p_val}')

print(f'Significant features: {significant_features}')
# Out:
# ROA(C): t-statistic=-20.371000246550334, p-value=1.3480464196848798e-89
# ROA(A): t-statistic=-20.36708962978169, p-value=1.453424003163958e-89
# ROA(B): t-statistic=-20.59226229040652, p-value=1.867512034084068e-91
# Net_Value(B): t-statistic=-18.100612154719915, p-value=1.4636946222454142e-71
# Net_Value(A): t-statistic=-18.063630730087446, p-value=2.7759711260126436e-71
# Net_Value(C): t-statistic=-17.96778874874424, p-value=1.4501252324742115e-70
# EPS: t-statistic=-21.879864151915534, p-value=1.2850660613455893e-102
# Net_profit_before_tax(Yuan): t-statistic=-20.955092472778485, p-value=1.533367351973881e-94
# Net_Worth: t-statistic=-21.003503318594138, p-value=5.8935839450365864e-95
# Net_profit_before_tax/paid: t-statistic=-21.088023673016618, p-value=1.1049936228065114e-95
# Working_capital: t-statistic=-16.287281271605863, p-value=1.5326177958071955e-58
# Retained_Earnings: t-statistic=-21.793854259365283, p-value=7.462352910828835e-102
# ...

# %%
len(significant_features)
# Out:
# 21

# %%
sns.countplot(x = 'Debt_ratio(Percent)', data = bank, palette = 'hls')
# Out:
# <Axes: xlabel='Debt_ratio(Percent)', ylabel='count'>

# %%
sns.pairplot(bank[0:5])
# Out:
# C:\Users\Rudresh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rudresh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rudresh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## 4. Feature Engineering and Selection:
# ### This part is done above already

# %% [markdown]
# # 5.Modelling :

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
bank.describe()
# Out:
#             ROA(C)       ROA(A)       ROA(B)  Net_Value(B)  Net_Value(A)  \
# count  6819.000000  6819.000000  6819.000000   6819.000000   6819.000000
# mean      0.505667     0.560507     0.554691      0.188108      0.188098
# std       0.051483     0.050087     0.050277      0.022773      0.022825
# min       0.387973     0.455122     0.442034      0.134676      0.134676
# 25%       0.476527     0.535543     0.527277      0.173613      0.173613
# 50%       0.502706     0.559802     0.552278      0.184400      0.184400
# 75%       0.535563     0.589157     0.584105      0.199570      0.199570
# max       0.624116     0.669579     0.669348      0.238507      0.238507
#
#        Net_Value(C)          EPS  Net_profit_before_tax(Yuan)    Net_Worth  \
# count   6819.000000  6819.000000                  6819.000000  6819.000000
# mean       0.188134     0.227074                     0.182461     0.887070
# std        0.022829     0.021870                     0.020916     0.052337
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ROA(C)                               6819 non-null   float64
#  1   ROA(A)                               6819 non-null   float64
#  2   ROA(B)                               6819 non-null   float64
#  3   Net_Value(B)                         6819 non-null   float64
#  4   Net_Value(A)                         6819 non-null   float64
#  5   Net_Value(C)                         6819 non-null   float64
#  6   EPS                                  6819 non-null   float64
#  7   Net_profit_before_tax(Yuan)          6819 non-null   float64
#  8   Net_Worth                            6819 non-null   float64
#  9   Net_profit_before_tax/paid           6819 non-null   float64
#  10  Working_capital                      6819 non-null   float64
# ...

# %% [markdown]
# ### Splitted values manually using slicing into training and testing

# %%
x_train=bank.iloc[:5500]
x_test=bank.iloc[5500:]

# %%
y_train=x_train.Bankrupt
y_test=x_test.Bankrupt

# %%
x_train=x_train.drop('Bankrupt',axis=1)
x_test=x_test.drop('Bankrupt',axis=1)

# %%
model=sm.Logit(y_train,x_train).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.093784
#          Iterations 13

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:               Bankrupt   No. Observations:                 5500
# Model:                          Logit   Df Residuals:                     5480
# Method:                           MLE   Df Model:                           19
# Date:                Mon, 17 Jun 2024   Pseudo R-squ.:                  0.3950
# Time:                        20:38:14   Log-Likelihood:                -515.81
# converged:                       True   LL-Null:                       -852.59
# Covariance Type:            nonrobust   LLR p-value:                1.431e-130
# ...
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ROA(C)                                -41.8643     10.770     -3.887      0.000     -62.973     -20.756
# ...

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# [[1297    0]
#  [  22    0]]
# Accuracy: 0.9833206974981046

# %%
y_pred = logistic_model.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(classification_report(y_test, y_pred))
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1297
#            1       0.00      0.00      0.00        22
#
#     accuracy                           0.98      1319
#    macro avg       0.49      0.50      0.50      1319
# weighted avg       0.97      0.98      0.98      1319
#
# Accuracy: 0.9833206974981046
# C:\Users\Rudresh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rudresh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # From the above accuracy we know that our model is overfitted
# ## Because of the data is biased towards non-bankrupt
# ## Total income/total expense affects the most as the z-value for this column is highest i.e -6.848

# %% [markdown]
# # Alternate Method :-
# ## We will take some samples here manually dividing it on bases of 0 and 1

# %%
bankrupt=bank[bank.Bankrupt==1]
non_bankrupt=bank[bank.Bankrupt==0].sample(400)
new_sample=pd.concat([bankrupt,non_bankrupt])

# %%
from scipy.stats import ttest_ind

# Hypothesis testing
significant_features = []
for column in new_sample.select_dtypes(include=[np.number]).columns:
    if column != 'Bankrupt':
        bankrupt = new_sample[new_sample['Bankrupt'] == 1][column]
        non_bankrupt = new_sample[new_sample['Bankrupt'] == 0][column]
        t_stat, p_val = ttest_ind(bankrupt, non_bankrupt)
        if p_val < 0.05:
            significant_features.append(column)
        print(f'{column}: t-statistic={t_stat}, p-value={p_val}')

print(f'Significant features: {significant_features}')
# Out:
# ROA(C): t-statistic=-17.634606155840967, p-value=1.1068652416039055e-56
# ROA(A): t-statistic=-17.790184861533987, p-value=1.769261524820151e-57
# ROA(B): t-statistic=-17.935315742039414, p-value=3.184005903346702e-58
# Net_Value(B): t-statistic=-15.501271941791456, p-value=5.052912518808814e-46
# Net_Value(A): t-statistic=-15.471810650680663, p-value=7.028785386619724e-46
# Net_Value(C): t-statistic=-15.363939506020468, p-value=2.3479793086818148e-45
# EPS: t-statistic=-19.34164525606766, p-value=1.5733023994868052e-65
# Net_profit_before_tax(Yuan): t-statistic=-18.53596898089784, p-value=2.5184946559848605e-61
# Net_Worth: t-statistic=-18.436690917318447, p-value=8.238906877409082e-61
# Net_profit_before_tax/paid: t-statistic=-18.596345308856726, p-value=1.223851068132807e-61
# Working_capital: t-statistic=-12.79312248910459, p-value=2.0674027479800355e-33
# Retained_Earnings: t-statistic=-18.839209134820425, p-value=6.671420145315387e-63
# ...

# %%
len(significant_features)
# Out:
# 21

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
new_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 620 entries, 0 to 2658
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ROA(C)                               620 non-null    float64
#  1   ROA(A)                               620 non-null    float64
#  2   ROA(B)                               620 non-null    float64
#  3   Net_Value(B)                         620 non-null    float64
#  4   Net_Value(A)                         620 non-null    float64
#  5   Net_Value(C)                         620 non-null    float64
#  6   EPS                                  620 non-null    float64
#  7   Net_profit_before_tax(Yuan)          620 non-null    float64
#  8   Net_Worth                            620 non-null    float64
#  9   Net_profit_before_tax/paid           620 non-null    float64
#  10  Working_capital                      620 non-null    float64
# ...

# %%
a=new_sample.iloc[:,0:15]

# %%
b=new_sample.iloc[:,15:]

# %%
new_sample2 = pd.concat([b,a])

# %%
response = new_sample2.iloc[:,-1]

# %%
predictor = new_sample2.iloc[:,0:21]

# %%
x_train, x_test, y_train, y_test = train_test_split(predictor,response, test_size=0.2)

# %%
x_train=sm.add_constant(x_train,prepend=False)
x_test=sm.add_constant(x_test,prepend=False)

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:               Bankrupt   No. Observations:                 5500
# Model:                          Logit   Df Residuals:                     5480
# Method:                           MLE   Df Model:                           19
# Date:                Mon, 17 Jun 2024   Pseudo R-squ.:                  0.3950
# Time:                        21:52:54   Log-Likelihood:                -515.81
# converged:                       True   LL-Null:                       -852.59
# Covariance Type:            nonrobust   LLR p-value:                1.431e-130
# ...
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ROA(C)                                -41.8643     10.770     -3.887      0.000     -62.973     -20.756
# ...

# %%
from sklearn.linear_model import LogisticRegression
logistic_model=LogisticRegression()
logistic_model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 logistic_model=LogisticRegression()
# ----> 3 logistic_model.fit(x_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#
# ...

# %%
y_pred = logistic_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 y_pred = logistic_model.predict(x_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:419, in LinearClassifierMixin.predict(self, X)
#     405 """
#     406 Predict class labels for samples in X.
#     407
#    (...)
#     416     Vector containing the class labels for each sample.
#     417 """
#     418 xp, _ = get_namespace(X)
# --> 419 scores = self.decision_function(X)
#     420 if len(scores.shape) == 1:
#     421     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:400, in LinearClassifierMixin.decision_function(self, X)
#     397 check_is_fitted(self)
#     398 xp, _ = get_namespace(X)
# --> 400 X = self._validate_data(X, accept_sparse="csr", reset=False)
# ...
